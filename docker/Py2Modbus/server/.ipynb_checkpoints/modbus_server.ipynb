# %%
# %ls
# Out:
# C:/
# dataset/
# dist/
# google-chrome-stable_current_amd64.deb
# google-chrome-stable_current_amd64.deb.1
# google-chrome-stable_current_amd64.deb.2
# google-chrome-stable_current_amd64.deb.3
# google-chrome-stable_current_amd64.deb.4
# google-chrome-stable_current_amd64.deb.5
# tencafe_20260615004854.csv
# tencafe_20260615004949.csv
# tencafe_20260615005438.csv
# tencafe_20260615005615.csv
# work/

# %%
# %pip install pymodbus
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
